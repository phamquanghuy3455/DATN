# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình
import tensorflow as tf
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense, Input #đầu ra

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# đọc dữ liệu từ file exel
df = pd.read_excel('/content/gdrive/MyDrive/dataset.xlsx', sheet_name='ADD')
print(df)
# Out:
#         YYYY    MM    DD   TIME             STAMP   Nhiệt độ     Độ mặn  \
# 0        NaN   NaN   NaN    NaN               NaN        NaN        NaN
# 1     2019.0   2.0   5.0  06:00  05/02/2019 06:00  18.000000  33.000000
# 2     2019.0   2.0   5.0  09:00  05/02/2019 09:00  18.500000  35.000000
# 3     2019.0   2.0   5.0  12:00  05/02/2019 12:00  19.000000  34.000000
# 4     2019.0   2.0   5.0  15:00  05/02/2019 15:00  19.537500  33.937500
# ...      ...   ...   ...    ...               ...        ...        ...
# 1883  2019.0  12.0  15.0  18:00  15/12/2019 18:00  23.281250  34.937500
# 1884  2019.0  12.0  16.0  00:00  16/12/2019 00:00  23.140625  34.968750
# 1885  2019.0  12.0  16.0  06:00  16/12/2019 06:00  23.320312  34.984375
# 1886  2019.0  12.0  16.0  09:00  16/12/2019 09:00  23.000000  35.000000
# 1887  2019.0  12.0  16.0  12:00  16/12/2019 12:00  23.500000  35.000000
#
#            PH       NH3       H2S        TSS       DO       COD Ghi chú  \
# 0         NaN       NaN       NaN        NaN      NaN       NaN     NaN
# 1     8.25000  0.060000  0.000000   6.200000  6.50000  5.600000    2018
# 2     8.20000  0.090000  0.000000   6.187500  6.70000  5.600000    2018
# 3     7.90000  0.120000  0.010000   6.500000  5.80000  5.100000    2018
# 4     7.91250  0.117062  0.009500   6.441406  5.79250  4.999375     AVE
# ...       ...       ...       ...        ...      ...       ...     ...
# 1883  8.02500  0.077500  0.001063   6.618750  5.97500  4.343750     AVE
# 1884  8.01250  0.088750  0.000531   6.259375  5.98750  4.371875     AVE
# 1885  8.05625  0.049375  0.002266   8.129687  5.94375  4.235938     AVE
# 1886  8.00000  0.100000  0.000000   5.900000  6.00000  4.400000    2019
# 1887  8.10000  0.010000  0.004000  10.000000  5.90000  4.100000    2019
#
#      Unnamed: 14 Unnamed: 15
# 0            NaN         NaN
# 1            TTG         NaN
# 2            TTG         NaN
# 3            TTG         NaN
# 4            NaN         NaN
# ...          ...         ...
# 1883         NaN         NaN
# 1884         NaN         NaN
# 1885         NaN         NaN
# 1886         TTG         NaN
# 1887         TTG         NaN
#
# [1888 rows x 16 columns]

# %%
required_cols = ['STAMP', 'Nhiệt độ', 'Độ mặn', 'PH']
df = df[required_cols]
df.head()

df.index = pd.to_datetime(df.STAMP, format='%d/%m/%Y %H:%M')

# %%
df = df.fillna(method='ffill')
print(df)
# Out:
#                                 STAMP   Nhiệt độ     Độ mặn       PH
# STAMP
# NaT                               NaN        NaN        NaN      NaN
# 2019-02-05 06:00:00  05/02/2019 06:00  18.000000  33.000000  8.25000
# 2019-02-05 09:00:00  05/02/2019 09:00  18.500000  35.000000  8.20000
# 2019-02-05 12:00:00  05/02/2019 12:00  19.000000  34.000000  7.90000
# 2019-02-05 15:00:00  05/02/2019 15:00  19.537500  33.937500  7.91250
# ...                               ...        ...        ...      ...
# 2019-12-15 18:00:00  15/12/2019 18:00  23.281250  34.937500  8.02500
# 2019-12-16 00:00:00  16/12/2019 00:00  23.140625  34.968750  8.01250
# 2019-12-16 06:00:00  16/12/2019 06:00  23.320312  34.984375  8.05625
# 2019-12-16 09:00:00  16/12/2019 09:00  23.000000  35.000000  8.00000
# 2019-12-16 12:00:00  16/12/2019 12:00  23.500000  35.000000  8.10000
#
# [1888 rows x 4 columns]
# <ipython-input-5-bd1449118e58>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')

# %%
for col in ['Nhiệt độ', 'Độ mặn', 'PH']:
    df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert to numeric, handle errors

# Perform resampling and calculate mean for numeric columns only
df_final = df[['Nhiệt độ', 'Độ mặn', 'PH']].resample('D').mean()

# If you need 'STAMP' in the final DataFrame:
df_final['STAMP'] = df_final.index.strftime('%d/%m/%Y') # Convert datetime index back to date string
df_final.head()
print(df_final)
# Out:
#              Nhiệt độ     Độ mặn        PH       STAMP
# STAMP
# 2019-02-05  18.821250  34.162500  8.092500  05/02/2019
# 2019-02-06  19.825521  34.458333  8.110417  06/02/2019
# 2019-02-07  20.942187  34.250000  8.118750  07/02/2019
# 2019-02-08  22.058854  34.041667  8.127083  08/02/2019
# 2019-02-09  23.359896  33.802083  8.137500  09/02/2019
# ...               ...        ...       ...         ...
# 2019-12-12  24.339193  34.636719  8.030339  12/12/2019
# 2019-12-13  24.129557  34.714844  8.053646  13/12/2019
# 2019-12-14  23.918620  34.777344  8.037240  14/12/2019
# 2019-12-15  23.509115  34.929688  8.061979  15/12/2019
# 2019-12-16  23.240234  34.988281  8.042187  16/12/2019
#
# [315 rows x 4 columns]

# %%
temp = df_final['Nhiệt độ'].values
salinity = df_final['Độ mặn'].values
ph = df_final['PH'].values

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df_final[['Nhiệt độ', 'Độ mặn', 'PH']])

# Create a new DataFrame with the scaled data
scaled_df_final = pd.DataFrame(scaled_data, columns=['Nhiệt độ', 'Độ mặn', 'PH'], index=df_final.index)

# %%
def calculate_correlation_matrix(df, window_size):
    correlations = []
    for i in range(len(df) - window_size + 1):
        window = df.iloc[i:i + window_size]
        # Only include numeric columns for correlation calculation
        corr_matrix = window[['Nhiệt độ', 'Độ mặn', 'PH']].corr(method='pearson').values  # Tính ma trận tương quan
        correlations.append(corr_matrix)
    return np.array(correlations)

window_size = 40  # Kích thước cửa sổ để tính ma trận tương quan
correlation_matrices = calculate_correlation_matrix(df_final, window_size)

# %%
X = correlation_matrices[:-1] # Ma trận tương quan (trừ mẫu cuối cùng)
y = df_final[['Nhiệt độ', 'Độ mặn', 'PH']].iloc[window_size:].values

# %%
targets = df_final[['Nhiệt độ', 'Độ mặn', 'PH']].iloc[window_size:].values

# %%
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

correlation_matrices_scaled = scaler_x.fit_transform(correlation_matrices.reshape(-1, 9)).reshape(-1, 3, 3)
targets_scaled = scaler_y.fit_transform(targets)

# %%
train_size = int(0.6 * len(correlation_matrices_scaled))
val_size = int(0.2 * len(correlation_matrices_scaled))
test_size = len(correlation_matrices_scaled) - train_size - val_size

# Chia dữ liệu thành Train, Validation và Test
X_train = correlation_matrices_scaled[:train_size]
y_train = targets_scaled[:train_size]

X_val = correlation_matrices_scaled[train_size:train_size + val_size]
y_val = targets_scaled[train_size:train_size + val_size]

X_test = correlation_matrices_scaled[:test_size]
y_test = targets_scaled[:test_size]

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((165, 3, 3), (165, 3), (55, 3, 3), (55, 3), (56, 3, 3), (56, 3))

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=32, return_sequences=False))
model.add(Dropout(0.2))

# Add a dense output layer
model.add(Dense(3))  # Dự báo 3 giá trị: Temperature, Salinity, pH

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 3, 128)              │          67,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 3, 64)               │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 3, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 129,507 (505.89 KB)
#  Trainable params: 129,507 (505.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',  # Theo dõi loss của tập kiểm tra
    patience=10,         # Dừng nếu không cải thiện sau 10 epoch
    restore_best_weights=True  # Phục hồi trọng số tốt nhất
)

# %%
path = '/content/gdrive/MyDrive/model.keras'
checkpoint = keras.callbacks.ModelCheckpoint(filepath=path, monitor='val_loss', save_best_only=True) # checkpoint callbacks

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - loss: 0.5964 - val_loss: 0.5698
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5576 - val_loss: 0.5248
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5146 - val_loss: 0.4676
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4553 - val_loss: 0.3916
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3795 - val_loss: 0.2905
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2759 - val_loss: 0.1655
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1547 - val_loss: 0.0506
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0658 - val_loss: 0.0441
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0747 - val_loss: 0.0653
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0842 - val_loss: 0.0288
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0463 - val_loss: 0.0196
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0320 - val_loss: 0.0317
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0385 - val_loss: 0.0372
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0441 - val_loss: 0.0321
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0349 - val_loss: 0.0241
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0324 - val_loss: 0.0207
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0324 - val_loss: 0.0203
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0329 - val_loss: 0.0189
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0297 - val_loss: 0.0176
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0282 - val_loss: 0.0182
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0279 - val_loss: 0.0190
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0265 - val_loss: 0.0187
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0274 - val_loss: 0.0178
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0286 - val_loss: 0.0175
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0298 - val_loss: 0.0177
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0259 - val_loss: 0.0176
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0255 - val_loss: 0.0175
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0291 - val_loss: 0.0179
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0281 - val_loss: 0.0180
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0245 - val_loss: 0.0177
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0256 - val_loss: 0.0173
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0278 - val_loss: 0.0173
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0247 - val_loss: 0.0173
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0277 - val_loss: 0.0174
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0283 - val_loss: 0.0175
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0264 - val_loss: 0.0174
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0268 - val_loss: 0.0174
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0287 - val_loss: 0.0177
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0250 - val_loss: 0.0173
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0268 - val_loss: 0.0168
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0270 - val_loss: 0.0167
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0288 - val_loss: 0.0167
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0273 - val_loss: 0.0166
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0243 - val_loss: 0.0166
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0233 - val_loss: 0.0167
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0255 - val_loss: 0.0170
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0248 - val_loss: 0.0171
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0258 - val_loss: 0.0167
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0249 - val_loss: 0.0164
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0238 - val_loss: 0.0165
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0258 - val_loss: 0.0168
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0265 - val_loss: 0.0177
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0260 - val_loss: 0.0180
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0254 - val_loss: 0.0178
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0262 - val_loss: 0.0172
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0269 - val_loss: 0.0165
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0261 - val_loss: 0.0164
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0245 - val_loss: 0.0163
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0230 - val_loss: 0.0164
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0255 - val_loss: 0.0165
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0260 - val_loss: 0.0166
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0268 - val_loss: 0.0165
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0246 - val_loss: 0.0165
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0248 - val_loss: 0.0163
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0227 - val_loss: 0.0165
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0269 - val_loss: 0.0170
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0239 - val_loss: 0.0171
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0233 - val_loss: 0.0164

# %%
plt.figure(figsize=(10, 6))
plt.plot(model.history.history['loss'], label='train_loss')
plt.plot(model.history.history['val_loss'], c='red', label='val_loss')
plt.legend();

# %%
y_pred = model.predict(X_test)

# Chuyển ngược dữ liệu về dạng gốc
y_test_inverse = scaler.inverse_transform(y_test)
y_pred_inverse = scaler.inverse_transform(y_pred)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 598ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
temp_mae = float(mean_absolute_error(y_test[0], y_pred[0]))# compare with unnoise_dataset
print('Độ lệch trung bình của nhiet do thuc te so với nhiet do du bao là: {:.3f}'.format(temp_mae))
sal_mae = float(mean_absolute_error(y_test[1], y_pred[1]))# compare with unnoise_dataset
print('Độ lệch trung bình của do man thuc te so với do man du bao là: {:.3f}'.format(sal_mae))
pH_mae = float(mean_absolute_error(y_test[2], y_pred[2]))# compare with unnoise_dataset
print('Độ lệch trung bình của pH thuc te so với pH du bao là: {:.3f}'.format(pH_mae))
# Out:
# Độ lệch trung bình của nhiet do thuc te so với nhiet do du bao là: 0.124
# Độ lệch trung bình của do man thuc te so với do man du bao là: 0.103
# Độ lệch trung bình của pH thuc te so với pH du bao là: 0.080

# %%
dates = df_final.index[window_size:]
test_dates = dates[:test_size]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np


# Tính MAE, MSE, RMSE, R2
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 0.09361960160476772
# MSE: 0.017121035945936263
# RMSE: 0.13084737653440462
# R2: -0.35293997653940656

# %%
import matplotlib.pyplot as plt

# Vẽ đồ thị cho từng tham số
labels = ['Nhiệt độ', 'Độ mặn', 'pH']

plt.figure(figsize=(10, 6))
for i in range(len(labels)):
    plt.subplot(3, 1, i + 1)
    plt.plot(test_dates, y_test_inverse[:, i], label=f'Thực tế - {labels[i]}', color='blue')
    plt.plot(test_dates, y_pred_inverse[:, i], label=f'Dự báo - {labels[i]}', color='red')
    plt.title(f'Dự báo {labels[i]} theo ngày')
    plt.xlabel('Thời gian')
    plt.ylabel(labels[i])
    plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

thresholds = {
    "Nhiệt độ": {"min": 28, "max": 30},
    "Độ mặn": {"min": 34, "max": 36},
    "pH": {"min": 8.1, "max": 8.2}
}
labels = ["Nhiệt độ", "Độ mặn", "pH"]

plt.figure(figsize=(10, 6))

for i in range(len(labels)):
    min_val = thresholds[labels[i]]["min"]
    max_val = thresholds[labels[i]]["max"]

    # Vẽ đồ thị
    plt.subplot(3, 1, i + 1)
    plt.plot(test_dates, y_pred_inverse[:, i], label=f'Dự báo - {labels[i]}', color='red')

    # Vẽ ngưỡng
    plt.axhline(min_val, color='green', linestyle='--', label=f'Min - {labels[i]}')
    plt.axhline(max_val, color='orange', linestyle='--', label=f'Max - {labels[i]}')

    # Đánh dấu điểm vượt ngưỡng
    exceed_min = y_pred_inverse[:, i] < min_val
    exceed_max = y_pred_inverse[:, i] > max_val
    plt.scatter(test_dates[exceed_min], y_pred_inverse[exceed_min, i], color='purple', label='Vượt Min', zorder=1)
    plt.scatter(test_dates[exceed_max], y_pred_inverse[exceed_max, i], color='black', label='Vượt Max', zorder=1)

    # Thêm thông tin
    plt.title(f'Dự báo và cảnh báo {labels[i]}')
    plt.xlabel('Thời gian')
    plt.ylabel(labels[i])
    plt.legend()
    plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
max_threshold = [27, 33, 8.1]  # Nhiệt độ, Độ mặn, pH
min_threshold = [26, 30, 7.0]    # Nhiệt độ, Độ mặn, pH

# %%
import matplotlib.pyplot as plt
import numpy as np

thresholds = {
    "Nhiệt độ": {"min": 22, "max": 28},
    "Độ mặn": {"min": 24, "max": 30},
    "pH": {"min": 25, "max": 29}
}
labels = ["Nhiệt độ", "Độ mặn", "pH"]

plt.figure(figsize=(10, 12))

for i in range(len(labels)):
    min_val = thresholds[labels[i]]["min"]
    max_val = thresholds[labels[i]]["max"]

    # Vẽ đồ thị
    plt.subplot(3, 1, i + 1)
    plt.plot(test_dates, y_test_inverse[:, i], label=f'Thực tế - {labels[i]}', color='blue')
    plt.plot(test_dates, y_pred_inverse[:, i], label=f'Dự báo - {labels[i]}', color='red')

    # Vẽ ngưỡng
    plt.axhline(min_val, color='green', linestyle='--', label=f'Min - {labels[i]}')
    plt.axhline(max_val, color='orange', linestyle='--', label=f'Max - {labels[i]}')

    # Đánh dấu điểm vượt ngưỡng
    exceed_min = y_pred_inverse[:, i] < min_val
    exceed_max = y_pred_inverse[:, i] > max_val
    plt.scatter(test_dates[exceed_min], y_pred_inverse[exceed_min, i], color='purple', label='Vượt Min', zorder=5)
    plt.scatter(test_dates[exceed_max], y_pred_inverse[exceed_max, i], color='black', label='Vượt Max', zorder=5)

    # Thêm thông tin
    plt.title(f'Dự báo và cảnh báo {labels[i]}')
    plt.xlabel('Thời gian')
    plt.ylabel(labels[i])
    plt.legend()
    plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-375903f7ee6c> in <cell line: 13>()
#      17     # Vẽ đồ thị
#      18     plt.subplot(3, 1, i + 1)
# ---> 19     plt.plot(test_dates, y_test_inverse[:, i], label=f'Thực tế - {labels[i]}', color='blue')
#      20     plt.plot(test_dates, y_pred_inverse[:, i], label=f'Dự báo - {labels[i]}', color='red')
#      21
#
# NameError: name 'test_dates' is not defined

# %%
pip install secure-smtplib
# Out:
# Collecting secure-smtplib
#   Downloading secure_smtplib-0.1.1-py2.py3-none-any.whl.metadata (511 bytes)
# Downloading secure_smtplib-0.1.1-py2.py3-none-any.whl (3.4 kB)
# Installing collected packages: secure-smtplib
# Successfully installed secure-smtplib-0.1.1

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import numpy as np
def send_alert_email(alert_indices, y_pred, labels, email_recipient):
    if alert_indices.size == 0:
        return # Không có cảnh báo, không cần gửi email

    # Tạo nội dung email
    subject = "Cảnh báo: Dự báo vượt ngưỡng"
    body = "Cảnh báo: Các giá trị dự báo đã vượt ngưỡng tại các thời điểm sau:\n\n"
    for i, idx in enumerate(alert_indices):
        body += f"Thời điểm {idx + 1}:\n"
        for j in range(len(labels)):
            body += f"  {labels[j]}: {y_pred[idx, j]:.2f}\n"
        body += "\n"

    # Cấu hình email
    sender_email = "phuy19092002@gmail.com"  # Thay bằng email của bạn
    sender_password = "huy1909200201676567030"        # Thay bằng mật khẩu email của bạn
    recipient_email = email_recipient

    # Tạo email
    message = MIMEMultipart()
    message["From"] = "phuy19092002@gmail.com"
    message["To"] = "phuy19092002@gmail.com"
    message["Subject"] = subject
    message.attach(MIMEText(body, "plain"))

    # Gửi email
    try:
        with smtplib.SMTP("smtp.gmail.com", 587) as server:
            server.starttls()
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, recipient_email, message.as_string())
        print("Cảnh báo đã được gửi qua email.")
    except Exception as e:
        print(f"Không thể gửi email: {e}")

# Xác định các chỉ số có cảnh báo
alert_indices = np.where((y_pred_inverse > max_threshold) | (y_pred_inverse < min_threshold))[0]

# Gửi email cảnh báo
send_alert_email(alert_indices, y_pred_inverse, labels, "phuy19092002@gmail.com")
# Out:
# Không thể gửi email: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials d9443c01a7336-219dc96312asm141870655ad.21 - gsmtp')
